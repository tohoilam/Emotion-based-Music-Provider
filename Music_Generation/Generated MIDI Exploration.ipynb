# %%
import os
import numpy as np
from MEC import MEC_predict, get_MIDI_features, get_info
import pretty_midi
from IPython import display

_SAMPLING_RATE = 16000

def play_audio(file_path, seconds=30):
  pm = pretty_midi.PrettyMIDI(file_path)
  waveform = pm.fluidsynth(fs=_SAMPLING_RATE)
  # Take a sample of the generated waveform to mitigate kernel resets
  waveform_short = waveform[:seconds*_SAMPLING_RATE]
  return display.Audio(waveform_short, rate=_SAMPLING_RATE)

# %%
model_path = "/Users/alexto/Documents/ProgrammingProjects/Emotion-based-Music-Provider/Music_Generation/MEC_model.h5"
midi_folder_path = "/Users/alexto/Documents/ProgrammingProjects/Emotion-based-Music-Provider/Music_Generation/generation/MIDI/monophonic"

emotion_class = ['Happiness', 'Anger', 'Sadness', 'Calmness']

midi_data_list = []
for emotion in emotion_class:
  emotion_midi_path = os.path.join(midi_folder_path, emotion)
  temp_midi_data_list = get_MIDI_features(emotion_midi_path, 1)
  for midi in temp_midi_data_list:
    midi['emotion'] = emotion
  
  midi_data_list.extend(temp_midi_data_list)


"""
Note Density: How many notes in one beat
Note Length: How long is one note (in beat unit)
Note Velocity: Volume [0, 127]
Pitch: [0, 127]

https://computermusicresource.com/midikeys.html
Scale: [0, 12) -> C, C#, D, D#, E, F, F#, G, G#, A, A#, B
Major: Minor = 0, Major = 1
80% Pitch Range: Middle 80% pitch range
Polyphony: Average Number of pitch per second (1.0 = Mono)
Pitch Entropy: IGNORE
Groove Consistency: Groove consistence or not (hamming distance)
"""
# Out:
# '\nNote Density: How many notes in one beat\nNote Length: How long is one note (in beat unit)\nNote Velocity: Volume [0, 127]\nPitch: [0, 127]\n\nhttps://computermusicresource.com/midikeys.html\nScale: [0, 12) -> C, C#, D, D#, E, F, F#, G, G#, A, A#, B\nMajor: Minor = 0, Major = 1\n80% Pitch Range: Middle 80% pitch range\nPolyphony: Average Number of pitch per second (1.0 = Mono)\nPitch Entropy: IGNORE\nGroove Consistency: Groove consistence or not (hamming distance)\n'

# %%
midi_data_list
# Out:
# [{'note_density_avg': 1.1176470588235294,
#   'note_density_sd': 0.3221897397089213,
#   'note_length_avg': 0.3339509610389614,
#   'note_length_sd': 0.15204949623071132,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 65.92207792207792,
#   'pitch_sd': 4.526304744853002,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 11.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.711065359510931,
#   'groove_consistency': 0.9965909090909091,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 3.0,
#   'note_density_sd': 0.7126966450997984,
#   'note_length_avg': 0.17647050000000045,
#   'note_length_sd': 0.0,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 71.32291666666667,
#   'pitch_sd': 3.648615010254652,
#   'scale': 8.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.5167571622010625,
#   'groove_consistency': 0.9953823953823954,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.4655172413793103,
#   'note_density_sd': 0.7925410299697381,
#   'note_length_avg': 0.389086255813953,
#   'note_length_sd': 0.40100950039387323,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.26744186046511,
#   'pitch_sd': 4.346675871322904,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.952752681383392,
#   'groove_consistency': 0.9918939393939394,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.3417721518987342,
#   'note_density_sd': 0.5485556627853279,
#   'note_length_avg': 0.2591759652777781,
#   'note_length_sd': 0.1602099987972617,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 65.24074074074075,
#   'pitch_sd': 4.973765192692945,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.3102881167672664,
#   'groove_consistency': 0.9953394706559263,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.725,
#   'note_density_sd': 0.49937460888595453,
#   'note_length_avg': 0.21293628237410106,
#   'note_length_sd': 0.1178482643224333,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.1726618705036,
#   'pitch_sd': 2.7113618059017828,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.9629315663830809,
#   'groove_consistency': 0.9957954545454546,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.8596491228070176,
#   'note_density_sd': 0.8873100783439853,
#   'note_length_avg': 0.40797840186915835,
#   'note_length_sd': 0.3861478521666693,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 74.4766355140187,
#   'pitch_sd': 3.7174652061234887,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 8.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.3143001206267906,
#   'groove_consistency': 0.991969696969697,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.8412698412698414,
#   'note_density_sd': 0.8945398605463727,
#   'note_length_avg': 0.19304507734806675,
#   'note_length_sd': 0.054720343912101455,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.58011049723757,
#   'pitch_sd': 6.180564975243341,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 19.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.3989042329002643,
#   'groove_consistency': 0.9945887445887446,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.8870967741935485,
#   'note_density_sd': 0.8251068104792685,
#   'note_length_avg': 0.18235285000000045,
#   'note_length_sd': 0.04518318768997491,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 71.53333333333333,
#   'pitch_sd': 3.913509365717112,
#   'scale': 9.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 12.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.6163815550867264,
#   'groove_consistency': 0.9942279942279942,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.7413793103448276,
#   'note_density_sd': 0.882010728443356,
#   'note_length_avg': 0.3412506568627447,
#   'note_length_sd': 0.2848645227217666,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 74.05882352941177,
#   'pitch_sd': 3.811292635982368,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.884622376075114,
#   'groove_consistency': 0.9914483821263482,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.0188679245283019,
#   'note_density_sd': 0.13605853869675427,
#   'note_length_avg': 0.11111099999999985,
#   'note_length_sd': 5.551115123125783e-17,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 74.25688073394495,
#   'pitch_sd': 3.8106650668657114,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.931271325219188,
#   'groove_consistency': 0.9954974271012007,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.2429906542056075,
#   'note_density_sd': 0.428889491797524,
#   'note_length_avg': 0.1368157835820894,
#   'note_length_sd': 0.05242269357418184,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.7910447761194,
#   'pitch_sd': 2.9297104611300413,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.6839475824236056,
#   'groove_consistency': 0.995964316057774,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.269230769230769,
#   'note_density_sd': 0.4980237076808982,
#   'note_length_avg': 0.14245430167597747,
#   'note_length_sd': 0.04031001662310251,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 71.14525139664805,
#   'pitch_sd': 1.196417986429592,
#   'scale': 6.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 2.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.3231700940172604,
#   'groove_consistency': 0.9928321678321679,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.125,
#   'note_density_sd': 0.38090587513752755,
#   'note_length_avg': 0.5006968749999998,
#   'note_length_sd': 0.4464714392771775,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 71.40625,
#   'pitch_sd': 5.231272401385728,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 20.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.7321397179737823,
#   'groove_consistency': 0.9953962703962704,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.349056603773585,
#   'note_density_sd': 0.4766718904399917,
#   'note_length_avg': 0.1157086965517239,
#   'note_length_sd': 0.028814677203628337,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.56551724137931,
#   'pitch_sd': 3.0236169094678607,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 3.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.6508646922239618,
#   'groove_consistency': 0.9960067969413764,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.2820512820512822,
#   'note_density_sd': 0.5969459859909135,
#   'note_length_avg': 0.18496356435643546,
#   'note_length_sd': 0.09318617703960044,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 72.22772277227723,
#   'pitch_sd': 1.4479838363985704,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.774240661767045,
#   'groove_consistency': 0.9944638694638694,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.0810810810810811,
#   'note_density_sd': 0.2729595929287048,
#   'note_length_avg': 0.521885,
#   'note_length_sd': 0.43547853067415965,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.75308641975309,
#   'pitch_sd': 3.283068664638185,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8885014294507068,
#   'groove_consistency': 0.9954545454545455,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.3063063063063063,
#   'note_density_sd': 0.533436805156305,
#   'note_length_avg': 0.13901193197278885,
#   'note_length_sd': 0.07147606659171966,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 66.42857142857143,
#   'pitch_sd': 7.117096404046372,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 18.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.477303179460846,
#   'groove_consistency': 0.9968877968877969,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.9402985074626864,
#   'note_density_sd': 1.0056645091297323,
#   'note_length_avg': 0.17423911363636296,
#   'note_length_sd': 0.048243965101142636,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 73.28282828282828,
#   'pitch_sd': 5.358916677875502,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 14.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8741008817613993,
#   'groove_consistency': 0.990976933514247,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.0,
#   'note_density_sd': 0.9446203958774616,
#   'note_length_avg': 0.18829158778625932,
#   'note_length_sd': 0.08832684571585539,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 73.74809160305344,
#   'pitch_sd': 2.7164849072194137,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 4.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.636160716906427,
#   'groove_consistency': 0.9930122116689281,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.5,
#   'note_density_sd': 0.5,
#   'note_length_avg': 0.3032967517605637,
#   'note_length_sd': 0.12774290349353684,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.25352112676056,
#   'pitch_sd': 3.2640522203912403,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.9631678228050604,
#   'groove_consistency': 0.9966028708133972,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.148936170212766,
#   'note_density_sd': 0.35602554320598956,
#   'note_length_avg': 0.18049436238532093,
#   'note_length_sd': 0.19600624306195166,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 74.94495412844037,
#   'pitch_sd': 2.1708446011401805,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 2.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.174729206778837,
#   'groove_consistency': 0.9971487603305785,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 3.014925373134328,
#   'note_density_sd': 0.9998886104145805,
#   'note_length_avg': 0.17323151970443285,
#   'note_length_sd': 0.03242699907749752,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 72.78817733990148,
#   'pitch_sd': 3.3083649955710777,
#   'scale': 11.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.133938506996481,
#   'groove_consistency': 0.9908412483039348,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.209090909090909,
#   'note_density_sd': 0.4066594408426372,
#   'note_length_avg': 0.2165798395522386,
#   'note_length_sd': 0.1779106210717731,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 71.74626865671642,
#   'pitch_sd': 3.644023049807048,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.7754286779934736,
#   'groove_consistency': 0.9958230958230958,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.368421052631579,
#   'note_density_sd': 0.48237638894271995,
#   'note_length_avg': 0.3287644179389313,
#   'note_length_sd': 0.20359458213475481,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 77.16793893129771,
#   'pitch_sd': 2.228040153939853,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 3.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.151090329942373,
#   'groove_consistency': 0.996555023923445,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.0105263157894737,
#   'note_density_sd': 0.10205641805087011,
#   'note_length_avg': 0.2568656597938144,
#   'note_length_sd': 0.2568211215567917,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.85567010309278,
#   'pitch_sd': 4.871524012097895,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.4992026170494857,
#   'groove_consistency': 0.9952898550724638,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.1386138613861385,
#   'note_density_sd': 0.37309789468152016,
#   'note_length_avg': 0.21109616379310372,
#   'note_length_sd': 0.18228686441927014,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 77.06896551724138,
#   'pitch_sd': 5.081616865164883,
#   'scale': 10.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 12.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.7813413346625806,
#   'groove_consistency': 0.991989198919892,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.1359223300970873,
#   'note_density_sd': 0.4191656921344252,
#   'note_length_avg': 0.332463813559322,
#   'note_length_sd': 0.2949316227410349,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 75.78813559322033,
#   'pitch_sd': 4.8132086885901355,
#   'scale': 10.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 8.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.483293403178177,
#   'groove_consistency': 0.993909973521624,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.3043478260869565,
#   'note_density_sd': 0.4906177066611814,
#   'note_length_avg': 0.1533106243093925,
#   'note_length_sd': 0.09152663075795513,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 79.30386740331491,
#   'pitch_sd': 3.5384918072126346,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.39554271519442,
#   'groove_consistency': 0.9952239789196311,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.0266666666666666,
#   'note_density_sd': 0.22939534045447013,
#   'note_length_avg': 0.16272173076923077,
#   'note_length_sd': 0.056866622594221906,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 74.01282051282051,
#   'pitch_sd': 3.3986935263028744,
#   'scale': 7.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.9999136053125577,
#   'groove_consistency': 0.9931143114311431,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.0909090909090908,
#   'note_density_sd': 0.2874797872880344,
#   'note_length_avg': 0.16896078620689656,
#   'note_length_sd': 0.14448104478901966,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.26206896551724,
#   'pitch_sd': 2.8551724137931034,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.3433060141813753,
#   'groove_consistency': 0.9949934123847167,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.1789473684210525,
#   'note_density_sd': 0.3833082411796447,
#   'note_length_avg': 0.19812345132743375,
#   'note_length_sd': 0.1428482449558621,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 67.00884955752213,
#   'pitch_sd': 2.2596717406732223,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 8.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.4353671095635365,
#   'groove_consistency': 0.9919034090909091,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.5104166666666665,
#   'note_density_sd': 1.0307237714613724,
#   'note_length_avg': 0.12127183884297489,
#   'note_length_sd': 0.04569034198395096,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 71.10330578512396,
#   'pitch_sd': 5.982211010647898,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.176881511348644,
#   'groove_consistency': 0.99375,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.1568627450980393,
#   'note_density_sd': 0.5730054586746062,
#   'note_length_avg': 0.7194448041666667,
#   'note_length_sd': 0.9366471993620384,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 78.0,
#   'pitch_sd': 4.08248290463863,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.699899339846218,
#   'groove_consistency': 0.9956580732700135,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.1666666666666667,
#   'note_density_sd': 0.37267799624996495,
#   'note_length_avg': 0.20803896933962265,
#   'note_length_sd': 0.2007384090848131,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 66.5754716981132,
#   'pitch_sd': 1.4662756903605814,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 1.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.8474665520882585,
#   'groove_consistency': 0.994066985645933,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.1770833333333335,
#   'note_density_sd': 1.0407808733777195,
#   'note_length_avg': 0.1640686792452827,
#   'note_length_sd': 0.11394729234468388,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 69.11792452830188,
#   'pitch_sd': 6.200293620098656,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.8577965149185705,
#   'groove_consistency': 0.9917057169634489,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.5909090909090908,
#   'note_density_sd': 0.8160747278481958,
#   'note_length_avg': 0.41121515887850457,
#   'note_length_sd': 0.2630971083757641,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.90654205607477,
#   'pitch_sd': 3.1608963305868274,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 6.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.78771897969665,
#   'groove_consistency': 0.9925373134328358,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.5151515151515151,
#   'note_density_sd': 0.7228400267803977,
#   'note_length_avg': 0.4422444455445543,
#   'note_length_sd': 0.298912408847205,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 77.97029702970298,
#   'pitch_sd': 4.347425425762406,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.2093067048910613,
#   'groove_consistency': 0.994708276797829,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 3.1875,
#   'note_density_sd': 0.3903123748998999,
#   'note_length_avg': 0.12804259546925587,
#   'note_length_sd': 0.041576821817955086,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 66.74433656957929,
#   'pitch_sd': 3.5071829155642527,
#   'scale': 3.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.053625198301272,
#   'groove_consistency': 0.9981724461105904,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.1666666666666667,
#   'note_density_sd': 0.37267799624996495,
#   'note_length_avg': 0.14066765044247784,
#   'note_length_sd': 0.09853529977253772,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 67.67256637168141,
#   'pitch_sd': 1.31997906845905,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 0.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.4334072183449373,
#   'groove_consistency': 0.9916193181818181,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.4880952380952381,
#   'note_density_sd': 0.6453874365918952,
#   'note_length_avg': 0.16566094488189,
#   'note_length_sd': 0.08417668492950629,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 67.00787401574803,
#   'pitch_sd': 4.927020250725291,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 15.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.2216779616618343,
#   'groove_consistency': 0.9945989304812834,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.11194024999999998,
#   'note_length_sd': 4.163336342344337e-17,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 77.25380710659898,
#   'pitch_sd': 1.7787659622836667,
#   'scale': 0.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 2.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.5001385137265681,
#   'groove_consistency': 0.9999536178107606,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.5172413793103448,
#   'note_density_sd': 0.7089261583958286,
#   'note_length_avg': 0.3101503759398496,
#   'note_length_sd': 0.2203260910778229,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 55.64661654135338,
#   'pitch_sd': 9.249422244685247,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 23.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.8169032334629396,
#   'groove_consistency': 0.9948275862068966,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.135135135135135,
#   'note_density_sd': 0.5020047465136949,
#   'note_length_avg': 0.3897058823529412,
#   'note_length_sd': 0.31471962586812785,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 58.05882352941177,
#   'pitch_sd': 6.155538761103399,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 18.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.3857727959889283,
#   'groove_consistency': 0.9954545454545455,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.541176470588235,
#   'note_density_sd': 0.819654750510605,
#   'note_length_avg': 0.13284866972477097,
#   'note_length_sd': 0.01944138276529471,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.51834862385321,
#   'pitch_sd': 2.9071460559091307,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 6.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.6949898717319494,
#   'groove_consistency': 0.9937967914438502,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.989795918367347,
#   'note_density_sd': 0.10049854899791943,
#   'note_length_avg': 0.11194024999999998,
#   'note_length_sd': 4.163336342344337e-17,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 78.26530612244898,
#   'pitch_sd': 2.892816650186314,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 4.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.458304599310279,
#   'groove_consistency': 0.999860853432282,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.069767441860465,
#   'note_density_sd': 0.45214469988892037,
#   'note_length_avg': 0.5319148936170213,
#   'note_length_sd': 0.5211408855042344,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 61.95744680851064,
#   'pitch_sd': 5.355281532256158,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 18.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.1947460988426744,
#   'groove_consistency': 0.9960292580982236,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.1278505393401015,
#   'note_length_sd': 0.039087906818062686,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.90862944162437,
#   'pitch_sd': 1.6744653362129884,
#   'scale': 0.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.6520263512006284,
#   'groove_consistency': 0.9999536178107606,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.1882352941176473,
#   'note_density_sd': 0.5839846421642756,
#   'note_length_avg': 0.1478307446808514,
#   'note_length_sd': 0.05222724307924186,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.94148936170212,
#   'pitch_sd': 2.4585460836908277,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 4.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.3657474913764505,
#   'groove_consistency': 0.9929946524064172,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.5647058823529414,
#   'note_density_sd': 0.9993769685456613,
#   'note_length_avg': 0.16896937500000023,
#   'note_length_sd': 0.09130082506087708,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 57.36818181818182,
#   'pitch_sd': 8.926257811221715,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 23.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.801005898698618,
#   'groove_consistency': 0.9913368983957219,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.6923076923076923,
#   'note_density_sd': 0.8213137116947161,
#   'note_length_avg': 0.2919060902255643,
#   'note_length_sd': 0.16768728222067342,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.17293233082707,
#   'pitch_sd': 5.21926921136322,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.219373720764916,
#   'groove_consistency': 0.9937967914438502,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.8955223880597014,
#   'note_density_sd': 0.7752578455654062,
#   'note_length_avg': 0.20955799224806168,
#   'note_length_sd': 0.11923934754908762,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 79.03875968992249,
#   'pitch_sd': 3.7321214134291836,
#   'scale': 4.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.682077046779866,
#   'groove_consistency': 0.9920948616600791,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.7638888888888888,
#   'note_density_sd': 1.0205262198650749,
#   'note_length_avg': 0.3391542421875003,
#   'note_length_sd': 0.2606390119618346,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 74.1875,
#   'pitch_sd': 6.752025159165211,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 17.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.9485869596571437,
#   'groove_consistency': 0.9933689839572193,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.3829787234042554,
#   'note_density_sd': 0.8392801243964264,
#   'note_length_avg': 0.26614843181818154,
#   'note_length_sd': 0.1436963945208071,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.6969696969697,
#   'pitch_sd': 4.4652520271255005,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 11.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.079489722394161,
#   'groove_consistency': 0.9929383116883117,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.635294117647059,
#   'note_density_sd': 0.9311227735251472,
#   'note_length_avg': 0.14486087389380572,
#   'note_length_sd': 0.04610221074288326,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 54.469026548672566,
#   'pitch_sd': 7.297800367428188,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 17.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.9242823330611465,
#   'groove_consistency': 0.9916577540106952,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 3.023529411764706,
#   'note_density_sd': 0.9200571668713952,
#   'note_length_avg': 0.15510891891891881,
#   'note_length_sd': 0.07052922957853222,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 56.3938223938224,
#   'pitch_sd': 6.511596461552924,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 15.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.6804285464505004,
#   'groove_consistency': 0.9936898395721925,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.392857142857143,
#   'note_density_sd': 1.1600272692079796,
#   'note_length_avg': 0.21609689781021862,
#   'note_length_sd': 0.07496898022533088,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 79.25547445255475,
#   'pitch_sd': 4.401441696588905,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 14.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.971097558513022,
#   'groove_consistency': 0.9918019480519481,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.2588235294117647,
#   'note_density_sd': 1.0533190252046774,
#   'note_length_avg': 0.23013936340206242,
#   'note_length_sd': 0.10829322313453714,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 80.02577319587628,
#   'pitch_sd': 5.833988191331992,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 17.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.7827411400715927,
#   'groove_consistency': 0.9940106951871658,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.7611940298507462,
#   'note_density_sd': 0.8824922686026556,
#   'note_length_avg': 0.20879131666666637,
#   'note_length_sd': 0.11002744363045451,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 79.80833333333334,
#   'pitch_sd': 7.4300020562282185,
#   'scale': 4.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 17.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.5166093801027536,
#   'groove_consistency': 0.9922659430122117,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.5454545454545454,
#   'note_density_sd': 0.5554637206007078,
#   'note_length_avg': 0.2736585218446599,
#   'note_length_sd': 0.22334953218650846,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 79.7864077669903,
#   'pitch_sd': 3.535260623827652,
#   'scale': 4.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 6.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.585705147031134,
#   'groove_consistency': 0.9922266139657444,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.2,
#   'note_density_sd': 1.0514059850764335,
#   'note_length_avg': 0.24590173770491766,
#   'note_length_sd': 0.09559939136330135,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.40163934426229,
#   'pitch_sd': 5.785311865243235,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.5587080359747203,
#   'groove_consistency': 0.9916528925619835,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.8695652173913044,
#   'note_density_sd': 1.0343806307278538,
#   'note_length_avg': 0.5142045454545454,
#   'note_length_sd': 0.3399489319632806,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 75.97727272727273,
#   'pitch_sd': 6.42964948982318,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 19.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.489905665275101,
#   'groove_consistency': 0.9913926499032882,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.1739130434782608,
#   'note_density_sd': 0.9395731645641003,
#   'note_length_avg': 0.3616504854368932,
#   'note_length_sd': 0.21679526867342339,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 73.48543689320388,
#   'pitch_sd': 5.43070035653988,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 21.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.6519894819395864,
#   'groove_consistency': 0.9911992263056093,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.2625,
#   'note_density_sd': 0.439992897669951,
#   'note_length_avg': 0.2639174338235297,
#   'note_length_sd': 0.1517265024827872,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 67.2843137254902,
#   'pitch_sd': 3.3705106699261647,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.222171708308083,
#   'groove_consistency': 0.9943181818181818,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.5,
#   'note_density_sd': 0.5,
#   'note_length_avg': 0.36376782079646,
#   'note_length_sd': 0.10171061516460327,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.60176991150442,
#   'pitch_sd': 1.117359585198295,
#   'scale': 4.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 1.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.490731730317412,
#   'groove_consistency': 0.9932121212121212,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.3571428571428572,
#   'note_density_sd': 0.4791574237499549,
#   'note_length_avg': 0.47390103571428605,
#   'note_length_sd': 0.34856264387756986,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.0909090909091,
#   'pitch_sd': 4.556091450291999,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.4065736296941322,
#   'groove_consistency': 0.9949090909090909,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.162162162162162,
#   'note_density_sd': 0.3685995053239421,
#   'note_length_avg': 0.3171174655172416,
#   'note_length_sd': 0.22531128732966244,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 64.50574712643679,
#   'pitch_sd': 5.150323197577336,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 14.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.243062849869874,
#   'groove_consistency': 0.9952272727272727,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 2.3404255319148937,
#   'note_density_sd': 0.9952353671086384,
#   'note_length_avg': 0.3581081081081081,
#   'note_length_sd': 0.2112319655440244,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 76.55855855855856,
#   'pitch_sd': 6.029484140731084,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 22.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.2167788456135353,
#   'groove_consistency': 0.9916827852998066,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.1176470588235294,
#   'note_density_sd': 0.32218973970892123,
#   'note_length_avg': 0.407002733766234,
#   'note_length_sd': 0.3665816705503619,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 67.11688311688312,
#   'pitch_sd': 3.6856126945720007,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 8.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8899096668131112,
#   'groove_consistency': 0.99625,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.5,
#   'note_density_sd': 0.5,
#   'note_length_avg': 0.36504419911504404,
#   'note_length_sd': 0.10522189124028132,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.70796460176992,
#   'pitch_sd': 1.1025426440427628,
#   'scale': 4.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 1.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.5033598822214265,
#   'groove_consistency': 0.9932121212121212,
#   'emotion': 'Happiness'},
#  {'note_density_avg': 1.0579710144927537,
#   'note_density_sd': 0.23368863038546525,
#   'note_length_avg': 0.5550175844594596,
#   'note_length_sd': 0.39978891052229065,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 54.78378378378378,
#   'pitch_sd': 3.167701316242777,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.798900753485456,
#   'groove_consistency': 0.9956963249516441,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.4536082474226804,
#   'note_density_sd': 0.5924023875694285,
#   'note_length_avg': 0.193390503521127,
#   'note_length_sd': 0.12289896657529159,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 75.35211267605634,
#   'pitch_sd': 3.160489316498076,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8411739319651517,
#   'groove_consistency': 0.9906747891283973,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.5492957746478873,
#   'note_density_sd': 0.9005277387687766,
#   'note_length_avg': 0.17314189189189189,
#   'note_length_sd': 0.0528574981855816,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 37.91891891891892,
#   'pitch_sd': 4.8511819589488985,
#   'scale': 9.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 0.941938162692791,
#   'groove_consistency': 0.995134443021767,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.3936170212765957,
#   'note_density_sd': 0.4885515958810653,
#   'note_length_avg': 0.23809450000000001,
#   'note_length_sd': 0.14432224203615276,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 54.946969696969695,
#   'pitch_sd': 3.1558372897032774,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.6401188854538056,
#   'groove_consistency': 0.9952127659574468,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.7634408602150538,
#   'note_density_sd': 0.7390468936533154,
#   'note_length_avg': 0.19264009545454577,
#   'note_length_sd': 0.1204621614200545,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 58.95151515151515,
#   'pitch_sd': 9.630636758334443,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 25.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.872255113032142,
#   'groove_consistency': 0.9944390715667312,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.4788732394366197,
#   'note_density_sd': 0.8534792905658094,
#   'note_length_avg': 0.15625,
#   'note_length_sd': 0.0,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 36.0,
#   'pitch_sd': 0.0,
#   'scale': 0.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': -2.0,
#   'polyphony': 1.0,
#   'pitch_entropy': -0.0,
#   'groove_consistency': 0.9956466069142126,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.5,
#   'note_density_sd': 0.5773502691896257,
#   'note_length_avg': 0.23867153082191836,
#   'note_length_sd': 0.12498787537431934,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 77.67123287671232,
#   'pitch_sd': 2.410336158676468,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 6.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.3499916106012506,
#   'groove_consistency': 0.9923149015932521,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.6804123711340206,
#   'note_density_sd': 0.6348372914779651,
#   'note_length_avg': 0.1794084375000005,
#   'note_length_sd': 0.11902273092924508,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 78.60365853658537,
#   'pitch_sd': 2.4510299040851806,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 4.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.8551607562699095,
#   'groove_consistency': 0.9927366447985004,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.323943661971831,
#   'note_density_sd': 0.599874350395686,
#   'note_length_avg': 0.18092105263157895,
#   'note_length_sd': 0.07956175409505149,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 36.01052631578948,
#   'pitch_sd': 0.6881667001549958,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': -1.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 0.2523008719388933,
#   'groove_consistency': 0.9970550576184379,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.44689655172413734,
#   'note_length_sd': 0.5291053180363209,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.08620689655173,
#   'pitch_sd': 3.1909596586921487,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 8.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8419875449318344,
#   'groove_consistency': 0.9958677685950413,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.7244444444444446,
#   'note_length_sd': 0.47382864017164855,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 64.5925925925926,
#   'pitch_sd': 4.461848639125227,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 11.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.3247595190378334,
#   'groove_consistency': 0.9957128099173553,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0166666666666666,
#   'note_density_sd': 0.12801909579781018,
#   'note_length_avg': 0.625,
#   'note_length_sd': 0.515876954571596,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 33.16129032258065,
#   'pitch_sd': 5.358723814091635,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 19.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.509601351473356,
#   'groove_consistency': 0.9961616161616161,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.3111111111111111,
#   'note_density_sd': 0.4629481479111035,
#   'note_length_avg': 0.26979166666666665,
#   'note_length_sd': 0.2230212955389886,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 35.36666666666667,
#   'pitch_sd': 6.540812046085885,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 17.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 4.012828122388884,
#   'groove_consistency': 0.9957575757575757,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.7559999999999996,
#   'note_length_sd': 0.6005997002996255,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 65.48,
#   'pitch_sd': 2.64,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 6.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8050298046890783,
#   'groove_consistency': 0.9962293388429752,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0116279069767442,
#   'note_density_sd': 0.10720400531735916,
#   'note_length_avg': 0.20170454545454544,
#   'note_length_sd': 0.09869859526159211,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 33.22727272727273,
#   'pitch_sd': 4.49425712520301,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 11.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.1250108360431357,
#   'groove_consistency': 0.9947906026557712,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0357142857142858,
#   'note_density_sd': 0.1855768722395226,
#   'note_length_avg': 1.432016041666667,
#   'note_length_sd': 1.190885478292268,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 63.36666666666667,
#   'pitch_sd': 4.020641187118735,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8389205950315937,
#   'groove_consistency': 0.9967272727272727,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.41,
#   'note_density_sd': 0.49183330509431744,
#   'note_length_avg': 0.22977164084507065,
#   'note_length_sd': 0.12685519156168856,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 57.21830985915493,
#   'pitch_sd': 7.003134305521378,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.7128751105854123,
#   'groove_consistency': 0.9964545454545455,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.6283526785714285,
#   'note_length_sd': 0.48735947156495807,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 66.26785714285714,
#   'pitch_sd': 7.041943399143072,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 18.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8883555868410786,
#   'groove_consistency': 0.9947846889952153,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.32205312500000016,
#   'note_length_sd': 0.24453924469758553,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 64.54444444444445,
#   'pitch_sd': 2.8988929347103487,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.571762870493237,
#   'groove_consistency': 0.9954066985645933,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0256410256410255,
#   'note_density_sd': 0.1580618975120251,
#   'note_length_avg': 0.8666686585365854,
#   'note_length_sd': 0.7812287958213372,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 69.78048780487805,
#   'pitch_sd': 2.824217527049781,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.5582617623457184,
#   'groove_consistency': 0.995085995085995,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.31,
#   'note_density_sd': 0.46249324319388707,
#   'note_length_avg': 0.27952745833333337,
#   'note_length_sd': 0.1266520677677725,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 58.946969696969695,
#   'pitch_sd': 7.087456262426527,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 16.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.037472683952224,
#   'groove_consistency': 0.9962727272727273,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.7606177325581396,
#   'note_length_sd': 0.5461010570400285,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 65.67441860465117,
#   'pitch_sd': 3.502297785491479,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.925388213763161,
#   'groove_consistency': 0.9967942583732058,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.54,
#   'note_density_sd': 0.5180733538795447,
#   'note_length_avg': 0.2599468903225809,
#   'note_length_sd': 0.12131608035091868,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 62.89032258064516,
#   'pitch_sd': 4.28736740328846,
#   'scale': 5.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 12.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.891944705143175,
#   'groove_consistency': 0.9963636363636363,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0294117647058822,
#   'note_density_sd': 0.16895772489817729,
#   'note_length_avg': 1.0881703819444448,
#   'note_length_sd': 0.9013088394129343,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 65.08333333333333,
#   'pitch_sd': 4.8383594556649285,
#   'scale': 1.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.425126559410829,
#   'groove_consistency': 0.996,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.8833333333333333,
#   'note_density_sd': 0.3210226714043038,
#   'note_length_avg': 0.3642623347826094,
#   'note_length_sd': 0.016983656998871353,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 51.00869565217391,
#   'pitch_sd': 4.737446848936972,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 15.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.547067895719829,
#   'groove_consistency': 0.9989393939393939,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0918367346938775,
#   'note_density_sd': 0.28879534077724295,
#   'note_length_avg': 0.14111111111111083,
#   'note_length_sd': 0.06288339198591565,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 52.101851851851855,
#   'pitch_sd': 2.892966614032035,
#   'scale': 0.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.9223929089480447,
#   'groove_consistency': 0.9938934802571167,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.6565656565656566,
#   'note_density_sd': 0.7542688768725038,
#   'note_length_avg': 0.15449101796407183,
#   'note_length_sd': 0.05587259547677246,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 51.76646706586826,
#   'pitch_sd': 2.5121170016051537,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.485464738682687,
#   'groove_consistency': 0.9953627180899908,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.8833333333333333,
#   'note_density_sd': 0.3210226714043038,
#   'note_length_avg': 0.3642623347826094,
#   'note_length_sd': 0.016983656998871353,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 51.00869565217391,
#   'pitch_sd': 4.737446848936972,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 15.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.547067895719829,
#   'groove_consistency': 0.9989393939393939,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0759493670886076,
#   'note_density_sd': 0.2649170827399538,
#   'note_length_avg': 0.21488372093023247,
#   'note_length_sd': 0.14422805089587964,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 53.848837209302324,
#   'pitch_sd': 3.8625134661027096,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.8876247908922306,
#   'groove_consistency': 0.9957792207792208,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.8833333333333333,
#   'note_density_sd': 0.3210226714043038,
#   'note_length_avg': 0.3642623347826094,
#   'note_length_sd': 0.016983656998871353,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 51.00869565217391,
#   'pitch_sd': 4.737446848936972,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 15.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.547067895719829,
#   'groove_consistency': 0.9989393939393939,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.024390243902439,
#   'note_density_sd': 0.21951219512195122,
#   'note_length_avg': 0.28235294117647053,
#   'note_length_sd': 0.28970429978665985,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 30.88235294117647,
#   'pitch_sd': 4.81275698096065,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.5252387085672403,
#   'groove_consistency': 0.9930178069353327,
#   'emotion': 'Anger'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.6472181727272727,
#   'note_length_sd': 0.5465998482309147,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 50.0,
#   'pitch_sd': 4.125309905713972,
#   'scale': 6.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.9088109702148306,
#   'groove_consistency': 0.9962594696969697,
#   'emotion': 'Anger'},
# ...
#   'groove_consistency': 0.9936950146627566,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 2.8360655737704916,
#   'note_density_sd': 0.8333288542386121,
#   'note_length_avg': 0.22828327414772734,
#   'note_length_sd': 0.09262844571600322,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 75.47727272727273,
#   'pitch_sd': 5.8939053126692444,
#   'scale': 10.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 14.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.8597517785632243,
#   'groove_consistency': 0.9914222873900294,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 2.0547945205479454,
#   'note_density_sd': 0.3660380607092435,
#   'note_length_avg': 0.28815789473684167,
#   'note_length_sd': 0.0584157181063766,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 60.19736842105263,
#   'pitch_sd': 6.941522161377684,
#   'scale': 4.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 19.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.9019965232475453,
#   'groove_consistency': 0.9987546699875467,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.5791123188405798,
#   'note_length_sd': 0.27856724117435727,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.18840579710145,
#   'pitch_sd': 4.111755372237727,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.6603719762394613,
#   'groove_consistency': 0.9986257928118393,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.6201742647058825,
#   'note_length_sd': 0.40308203783770935,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 64.20588235294117,
#   'pitch_sd': 3.9614273405421008,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 10.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.615823314489725,
#   'groove_consistency': 0.9963530655391121,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.9726027397260273,
#   'note_density_sd': 0.2853789952876666,
#   'note_length_avg': 0.30308219178082146,
#   'note_length_sd': 0.05680494224703734,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 60.773972602739725,
#   'pitch_sd': 7.510513679188447,
#   'scale': 4.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 19.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.5535498030749704,
#   'groove_consistency': 0.999252801992528,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0384615384615385,
#   'note_density_sd': 0.19230769230769232,
#   'note_length_avg': 0.5172896341463412,
#   'note_length_sd': 0.33519672916081694,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 65.08536585365853,
#   'pitch_sd': 3.592679615185664,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.698284688670617,
#   'groove_consistency': 0.9966701902748414,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 2.0,
#   'note_density_sd': 0.28669108954049793,
#   'note_length_avg': 0.29797297297297254,
#   'note_length_sd': 0.05779693552452671,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 58.810810810810814,
#   'pitch_sd': 5.366753701124337,
#   'scale': 4.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 12.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.3463444742448782,
#   'groove_consistency': 0.9990037359900373,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.8867924528301887,
#   'note_density_sd': 0.31684633252352196,
#   'note_length_avg': 0.443415841584158,
#   'note_length_sd': 0.1092439832112327,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.91089108910892,
#   'pitch_sd': 4.997224992113301,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 14.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.1728673705931416,
#   'groove_consistency': 0.998885077186964,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.7567567567567568,
#   'note_density_sd': 0.7677769033157725,
#   'note_length_avg': 0.32124121590909016,
#   'note_length_sd': 0.26368152352074714,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 62.53030303030303,
#   'pitch_sd': 4.737726398107445,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 11.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.229135225565101,
#   'groove_consistency': 0.9944848484848485,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.9056603773584906,
#   'note_density_sd': 0.29230062990244654,
#   'note_length_avg': 0.43078431372548975,
#   'note_length_sd': 0.058578944127709066,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 66.51960784313725,
#   'pitch_sd': 4.872351753611276,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 16.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.1000366428472854,
#   'groove_consistency': 0.9992281303602059,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.8243243243243243,
#   'note_density_sd': 0.7043898664822783,
#   'note_length_avg': 0.2958309543795615,
#   'note_length_sd': 0.1958622062484427,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 63.90510948905109,
#   'pitch_sd': 6.032615986862287,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 16.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.6653793322835178,
#   'groove_consistency': 0.9956969696969697,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.635135135135135,
#   'note_density_sd': 0.8787940804264383,
#   'note_length_avg': 0.3286569549180321,
#   'note_length_sd': 0.29849104962168316,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 61.92622950819672,
#   'pitch_sd': 5.797353880254314,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.697754069089453,
#   'groove_consistency': 0.9928746928746929,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.8113207547169812,
#   'note_density_sd': 0.39125361044014567,
#   'note_length_avg': 0.4333891752577315,
#   'note_length_sd': 0.09768749464301497,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 67.75257731958763,
#   'pitch_sd': 4.1443811865318825,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 16.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.4810482653428867,
#   'groove_consistency': 0.9985420240137222,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.4506719178082196,
#   'note_length_sd': 0.3224932869627646,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 81.87671232876713,
#   'pitch_sd': 6.846547386020641,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 17.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.6057991606106983,
#   'groove_consistency': 0.9970427163198248,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.1486486486486487,
#   'note_density_sd': 0.3557417994888698,
#   'note_length_avg': 0.4952668247126431,
#   'note_length_sd': 0.34261626614275564,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 52.264367816091955,
#   'pitch_sd': 3.9053743403513246,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 12.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.0155066822805887,
#   'groove_consistency': 0.9960606060606061,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.878300423076923,
#   'note_length_sd': 0.6921560086624956,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 63.69230769230769,
#   'pitch_sd': 4.403692193031487,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 9.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.9560449405465063,
#   'groove_consistency': 0.9972429210134128,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 1.009949811111111,
#   'note_length_sd': 0.8291605026272946,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 62.422222222222224,
#   'pitch_sd': 2.275364575319147,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 6.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.2349605159981207,
#   'groove_consistency': 0.9936661698956781,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0595238095238095,
#   'note_density_sd': 0.23660246326609272,
#   'note_length_avg': 0.4593822222222219,
#   'note_length_sd': 0.3272508272896012,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 79.75555555555556,
#   'pitch_sd': 6.006128557308242,
#   'scale': 8.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 13.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.601108406360902,
#   'groove_consistency': 0.990909090909091,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.162162162162162,
#   'note_density_sd': 0.43579771612424595,
#   'note_length_avg': 0.4227939062499995,
#   'note_length_sd': 0.2354740989320387,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 53.21590909090909,
#   'pitch_sd': 4.085586815636057,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.015587141747784,
#   'groove_consistency': 0.9943636363636363,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.9492533199999998,
#   'note_length_sd': 0.7337817868261366,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 64.66,
#   'pitch_sd': 2.6046880811337085,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 6.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.6572384864776484,
#   'groove_consistency': 0.9972429210134128,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.48552730158730123,
#   'note_length_sd': 0.4073009679755253,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 54.03174603174603,
#   'pitch_sd': 2.8338557163720264,
#   'scale': 2.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 3.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.5719710486487726,
#   'groove_consistency': 0.9944717444717445,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.6157852459016391,
#   'note_length_sd': 0.4121613255836926,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 85.57377049180327,
#   'pitch_sd': 2.4592349629638264,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 4.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.48718302601163,
#   'groove_consistency': 0.9956709956709957,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.3559953703703702,
#   'note_length_sd': 0.2898341619163478,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 68.46296296296296,
#   'pitch_sd': 3.8859336213758686,
#   'scale': 0.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 17.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.402259338610228,
#   'groove_consistency': 0.9985123966942149,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.869047619047619,
#   'note_density_sd': 0.33734826941201795,
#   'note_length_avg': 0.13985414308176053,
#   'note_length_sd': 0.03194344606956337,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 80.69811320754717,
#   'pitch_sd': 2.1213343284583885,
#   'scale': 4.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.0794927183955614,
#   'groove_consistency': 0.9988636363636364,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.21124999999999985,
#   'note_length_sd': 2.7755575615628914e-17,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.14285714285714,
#   'pitch_sd': 1.9032732277820326,
#   'scale': 0.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 3.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.87479762862974,
#   'groove_consistency': 1.0,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.21124999999999985,
#   'note_length_sd': 2.7755575615628914e-17,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 70.03571428571429,
#   'pitch_sd': 1.9361623097756857,
#   'scale': 4.0,
#   'major_minor': 0.0,
#   '80%_pitch_range': 3.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 1.87479762862974,
#   'groove_consistency': 1.0,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.5119047619047619,
#   'note_density_sd': 0.49985825655278615,
#   'note_length_avg': 0.14699813476562462,
#   'note_length_sd': 0.04540507750362569,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 77.3203125,
#   'pitch_sd': 4.943325035069386,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 12.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.237090061125768,
#   'groove_consistency': 0.9968614718614719,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.9523809523809523,
#   'note_density_sd': 0.21295885499997996,
#   'note_length_avg': 0.1395532196969692,
#   'note_length_sd': 0.03139551859250399,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 79.65454545454546,
#   'pitch_sd': 2.751648641802562,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 8.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.526195919779308,
#   'groove_consistency': 0.9995670995670995,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.46605328947368424,
#   'note_length_sd': 0.24539293682403882,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 85.47368421052632,
#   'pitch_sd': 3.901665245731711,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 8.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.9874068805388916,
#   'groove_consistency': 0.9964403066812705,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.563517647058823,
#   'note_length_sd': 0.4855358667738929,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 77.3970588235294,
#   'pitch_sd': 9.817660716164328,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 25.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.67882010626266,
#   'groove_consistency': 0.9951298701298701,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0169491525423728,
#   'note_density_sd': 0.12908090009938827,
#   'note_length_avg': 0.6313050860655736,
#   'note_length_sd': 0.539133463388376,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 72.45901639344262,
#   'pitch_sd': 2.972958842368959,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.662501066255349,
#   'groove_consistency': 0.9951515151515151,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.527027027027027,
#   'note_density_sd': 0.6414294208813955,
#   'note_length_avg': 0.2985829561403506,
#   'note_length_sd': 0.20101668017620522,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 72.85964912280701,
#   'pitch_sd': 3.238683924234614,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 7.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 3.002814762536381,
#   'groove_consistency': 0.9937960687960687,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.0,
#   'note_density_sd': 0.0,
#   'note_length_avg': 0.9380465116279073,
#   'note_length_sd': 0.41788580397310676,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 85.5813953488372,
#   'pitch_sd': 2.903346570565694,
#   'scale': 3.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.567831978347603,
#   'groove_consistency': 0.9958874458874459,
#   'emotion': 'Calmness'},
#  {'note_density_avg': 1.178082191780822,
#   'note_density_sd': 0.38258191900736827,
#   'note_length_avg': 0.4393235488505746,
#   'note_length_sd': 0.3498285127490297,
#   'note_velocity_avg': 100.0,
#   'note_velocity_sd': 0.0,
#   'pitch_avg': 72.7816091954023,
#   'pitch_sd': 3.3576992922128897,
#   'scale': 2.0,
#   'major_minor': 1.0,
#   '80%_pitch_range': 5.0,
#   'polyphony': 1.0,
#   'pitch_entropy': 2.4744022615015657,
#   'groove_consistency': 0.9942260442260442,
#   'emotion': 'Calmness'}]

# %%
len(midi_data_list)
# Out:
# 249

# %%
import json

with open("processed_data_info.json", "w") as fp:
  json.dump(midi_data_list, fp)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Major Minor Scale bar graph

# %%
import matplotlib.pyplot as plt

label = ["-C", "-C#", "-D", "-D#", "-E", "-F", "-F#", "-G", "-G#", "-A", "-A#", "-B", "C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
angry = [ 0 for i in range(24) ]
happiness = [ 0 for i in range(24) ]
calmness = [ 0 for i in range(24) ]
sadness = [ 0 for i in range(24) ]

for midi in midi_data_list:
  num = midi['major_minor'] * 12 + midi['scale']
  num = int(num)
  if (midi['emotion'] == 'Anger'):
    angry[num] += 1
  elif (midi['emotion'] == 'Happiness'):
    happiness[num] += 1
  elif (midi['emotion'] == 'Calmness'):
    calmness[num] += 1
  elif (midi['emotion'] == 'Sadness'):
    sadness[num] += 1

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 14))
axs[0, 0].bar(label, angry)
axs[0, 0].set_xlabel('Anger')
axs[0, 0].set_ylabel('Number of samples')
axs[0, 0].set_title('Anger')

axs[0, 1].bar(label, happiness)
axs[0, 1].set_xlabel('Happiness')
axs[0, 1].set_ylabel('Number of samples')
axs[0, 1].set_title('Happiness')

axs[1, 0].bar(label, calmness)
axs[1, 0].set_xlabel('Calmness')
axs[1, 0].set_ylabel('Number of samples')
axs[1, 0].set_title('Calmness')

axs[1, 1].bar(label, sadness)
axs[1, 1].set_xlabel('Sadness')
axs[1, 1].set_ylabel('Number of samples')
axs[1, 1].set_title('Sadness')
plt.show()

# %% [markdown]
# ## Plot violin

# %%
import matplotlib.pyplot as plt

def box_plot(ax, points, name):
  vp = ax.boxplot(points, positions=[2, 4, 6, 8], widths=1.5, patch_artist=True,
                  showmeans=True, showfliers=False,
                  medianprops={"color": "white", "linewidth": 0.5},
                  boxprops={"facecolor": "C0", "edgecolor": "white",
                            "linewidth": 1.0},
                  whiskerprops={"color": "C0", "linewidth": 1.5},
                  capprops={"color": "C0", "linewidth": 1.5})

  # ax.set_ylim((0, 6))
  ax.set_xticklabels(('Anger', 'Happiness', 'Calmness', 'Sadness'))
  ax.set_title(name)
  ax.set_xlabel('Emotions')
  ax.set_ylabel(name)

  return ax, vp

def violin_plot(ax, points, name):
  vp = ax.violinplot(points, [2, 4, 6, 8], widths=2,
                    showmeans=True, showmedians=True, showextrema=True)
  for body in vp['bodies']:
    body.set_alpha(0.9)

  # ax.set_ylim((0, 6))
  ax.set_xticklabels(('', '',  'Anger', '', 'Happiness', '', 'Calmness', '', 'Sadness'))
  ax.set_title(name)
  ax.set_xlabel('Emotions')
  ax.set_ylabel(name)

  return ax, vp

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 10))

# Note density average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['note_density_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 0], vp = box_plot(ax[0, 0], points, 'Note Density Average Box Plot')


# Note length average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['note_length_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 1], vp = box_plot(ax[0, 1], points, 'Note Length Average Box Plot')


# Note velocity average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['note_velocity_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 2], vp = box_plot(ax[0, 2], points, 'Note Velocity Average Box Plot')




# Note density average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['note_density_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 0], vp = violin_plot(ax[1, 0], points, 'Note Density Average Violin Plot')


# Note length average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['note_length_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 1], vp = violin_plot(ax[1, 1], points, 'Note Length Average Violin Plot')


# Note velocity average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['note_velocity_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 2], vp = violin_plot(ax[1, 2], points, 'Note Velocity Average Violin Plot')

plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 10))

# Note density average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['pitch_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 0], vp = box_plot(ax[0, 0], points, 'Pitch Average Box Plot')


# Note length average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['80%_pitch_range']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 1], vp = box_plot(ax[0, 1], points, '80% Pitch Range Box Plot')


# Note velocity average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['pitch_entropy']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 2], vp = box_plot(ax[0, 2], points, 'Pitch Entropy Box Plot')




# Note density average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['pitch_avg']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 0], vp = violin_plot(ax[1, 0], points, 'Pitch Average Violin Plot')


# Note length average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['80%_pitch_range']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 1], vp = violin_plot(ax[1, 1], points, '80% Pitch Range Violin Plot')


# Note velocity average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['pitch_entropy']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 2], vp = violin_plot(ax[1, 2], points, 'Pitch Entropy Violin Plot')

plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 10))

# Note density average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['polyphony']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 0], vp = box_plot(ax[0, 0], points, 'Polyphony Box Plot')


# Note length average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['groove_consistency']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[0, 1], vp = box_plot(ax[0, 1], points, 'Groove Consistency Box Plot')


# # Note velocity average
# angry = []
# happiness = []
# calmness = []
# sadness = []

# for midi in midi_data_list:
#   num = midi['pitch_entropy']
#   if (midi['emotion'] == 'Angry'):
#     angry.append(num)
#   elif (midi['emotion'] == 'Happiness'):
#     happiness.append(num)
#   elif (midi['emotion'] == 'Calmness'):
#     calmness.append(num)
#   elif (midi['emotion'] == 'Sadness'):
#     sadness.append(num)

# points = (angry, happiness, calmness, sadness)
# ax[0, 2], vp = box_plot(ax[0, 2], points, 'Pitch Entropy Box Plot')




# Note density average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['polyphony']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 0], vp = violin_plot(ax[1, 0], points, 'Polyphony Violin Plot')


# Note length average
angry = []
happiness = []
calmness = []
sadness = []

for midi in midi_data_list:
  num = midi['groove_consistency']
  if (midi['emotion'] == 'Anger'):
    angry.append(num)
  elif (midi['emotion'] == 'Happiness'):
    happiness.append(num)
  elif (midi['emotion'] == 'Calmness'):
    calmness.append(num)
  elif (midi['emotion'] == 'Sadness'):
    sadness.append(num)

points = (angry, happiness, calmness, sadness)
ax[1, 1], vp = violin_plot(ax[1, 1], points, 'Groove Consistency Violin Plot')


# # Note velocity average
# angry = []
# happiness = []
# calmness = []
# sadness = []

# for midi in midi_data_list:
#   num = midi['pitch_entropy']
#   if (midi['emotion'] == 'Angry'):
#     angry.append(num)
#   elif (midi['emotion'] == 'Happiness'):
#     happiness.append(num)
#   elif (midi['emotion'] == 'Calmness'):
#     calmness.append(num)
#   elif (midi['emotion'] == 'Sadness'):
#     sadness.append(num)

# points = (angry, happiness, calmness, sadness)
# ax[1, 2], vp = violin_plot(ax[1, 2], points, 'Pitch Entropy Violin Plot')

plt.show()
